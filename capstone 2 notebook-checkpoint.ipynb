# %%
#Import Libraries

import matplotlib as mpl
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns
import pandas as pd
import statsmodels.api as sm
sns.set_style("darkgrid")
mpl.rcParams['figure.figsize'] = (20,5)

# %%
df_raw=pd.read_csv("Video Games Sales.csv",index_col='index')

df_raw.describe()
# Out:
#             Rank         Year  North America       Europe        Japan  \
# count  1907.0000  1878.000000    1907.000000  1907.000000  1907.000000
# mean    954.0000  2003.766773       1.258789     0.706675     0.317493
# std     550.6478     5.895369       1.956560     1.148904     0.724945
# min       1.0000  1983.000000       0.000000     0.000000     0.000000
# 25%     477.5000  2000.000000       0.510000     0.230000     0.000000
# 50%     954.0000  2005.000000       0.810000     0.440000     0.020000
# 75%    1430.5000  2008.000000       1.375000     0.810000     0.300000
# max    1907.0000  2012.000000      40.430000    28.390000     7.200000
#
#        Rest of World       Global       Review
# count    1907.000000  1907.000000  1907.000000
# mean        0.206471     2.489240    79.038977
# std         0.343093     3.563159    10.616899
# min         0.000000     0.830000    30.500000
# 25%         0.060000     1.110000    74.000000
# ...

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1907 entries, 0 to 1906
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           1907 non-null   int64
#  1   Game Title     1907 non-null   object
#  2   Platform       1907 non-null   object
#  3   Year           1878 non-null   float64
#  4   Genre          1907 non-null   object
#  5   Publisher      1905 non-null   object
#  6   North America  1907 non-null   float64
#  7   Europe         1907 non-null   float64
#  8   Japan          1907 non-null   float64
#  9   Rest of World  1907 non-null   float64
#  10  Global         1907 non-null   float64
#  11  Review         1907 non-null   float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 193.7+ KB

# %%
df_raw.head()
# Out:
#    index  Rank         Game Title Platform    Year     Genre Publisher  \
# 0      0     1         Wii Sports      Wii  2006.0    Sports  Nintendo
# 1      1     2  Super Mario Bros.      NES  1985.0  Platform  Nintendo
# 2      2     3     Mario Kart Wii      Wii  2008.0    Racing  Nintendo
# 3      3     4  Wii Sports Resort      Wii  2009.0    Sports  Nintendo
# 4      4     5             Tetris       GB  1989.0    Puzzle  Nintendo
#
#    North America  Europe  Japan  Rest of World  Global  Review
# 0          40.43   28.39   3.77           8.54   81.12   76.28
# 1          29.08    3.58   6.81           0.77   40.24   91.00
# 2          14.50   12.22   3.63           3.21   33.55   82.07
# 3          14.82   10.51   3.18           3.01   31.52   82.65
# 4          23.20    2.26   4.22           0.58   30.26   88.00

# %% [markdown]
# # Data Cleansing

# %%
df_raw.isna().sum()
# Out:
# Rank              0
# Game Title        0
# Platform          0
# Year             29
# Genre             0
# Publisher         2
# North America     0
# Europe            0
# Japan             0
# Rest of World     0
# Global            0
# Review            0
# dtype: int64

# %%
#drop null values
df=df_raw.dropna(axis=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1878 entries, 0 to 1906
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           1878 non-null   int64
#  1   Game Title     1878 non-null   object
#  2   Platform       1878 non-null   object
#  3   Year           1878 non-null   float64
#  4   Genre          1878 non-null   object
#  5   Publisher      1878 non-null   object
#  6   North America  1878 non-null   float64
#  7   Europe         1878 non-null   float64
#  8   Japan          1878 non-null   float64
#  9   Rest of World  1878 non-null   float64
#  10  Global         1878 non-null   float64
#  11  Review         1878 non-null   float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 190.7+ KB

# %%
df.isna().sum()
# Out:
# Rank             0
# Game Title       0
# Platform         0
# Year             0
# Genre            0
# Publisher        0
# North America    0
# Europe           0
# Japan            0
# Rest of World    0
# Global           0
# Review           0
# dtype: int64

# %% [markdown]
# Part 1: Top-selling video games of all time.
#
# Reveal the iconic titles that have left a mark on the industry. From timeless classics to modern blockbusters, we explore the correlation between sales figures and factors such as platform, genre, and release year. By analyzing the global rankings, we gain a deeper understanding of the games that have resonated most with players across the world.

# %% [markdown]
# Part 2: Platform Wars and Regional Preferences
# Next, we shift our focus to the battle of platforms and regional preferences.
#
# We uncover insights on how different platforms, such as consoles or portablesystems have fared in terms of sales.
#
# By comparing sales figures in North America, Europe, Japan, and the Rest of the World, we unveil the diverging tastes and preferences of gamers in different regions.
#
# This analysis offers valuable information to publishers and developers seeking to optimize their strategies for specific markets.

# %% [markdown]
# Part 3: Genre Dynamics and Publisher Influence
#
# Explore the relationship between genres, sales, and publisher influence.
#
# Identify the genres that have captured the hearts of gamers worldwide and examine how sales figures vary across different genres.
#
# Furthermore, we shed light on the role of publishers in shaping the success of video games. Through this analysis, we provide insights into the key genres and publishers that have shaped the industry's landscape.

# %% [markdown]
# Part 4: Unveiling the Global Picture
# Finally, we conclude our journey by zooming out to capture the global picture of video game sales.
#
# By aggregating sales data from all regions, we present a comprehensive overview of the gaming industry's financial landscape. We analyze the growth patterns, identify emerging trends, and discuss the factors that contribute to global success. This analysis provides strategic insights for stakeholders, enabling them to make informed decisions and adapt to the ever-changing gaming landscape.

# %% [markdown]
# Conclusion:
# Through the lens of critical sales data, we uncovered the evolution of video game sales across platforms, genres, and regions.
#
# From the rise of iconic titles to the influence of publishers and the dynamics of global sales, this dataset has illuminated the multifaceted nature of the gaming industry.
#
# Armed with these insights, we can navigate the future of gaming with greater clarity and understanding.

# %% [markdown]
# ## Insights

# %%
df
# Out:
#        Rank                        Game Title Platform    Year         Genre  \
# index
# 0         1                        Wii Sports      Wii  2006.0        Sports
# 1         2                 Super Mario Bros.      NES  1985.0      Platform
# 2         3                    Mario Kart Wii      Wii  2008.0        Racing
# 3         4                 Wii Sports Resort      Wii  2009.0        Sports
# 4         5                            Tetris       GB  1989.0        Puzzle
# ...     ...                               ...      ...     ...           ...
# 1902   1903  Lizzie McGuire 2: Lizzie Diaries      GBA  2004.0        Action
# 1903   1904              Xenoblade Chronicles      Wii  2010.0  Role-Playing
# 1904   1905                     SingStar Abba      PS3  2008.0          Misc
# 1905   1906    FIFA Soccer World Championship      PS2  2000.0        Sports
# 1906   1907        WWE SmackDown vs. Raw 2011     X360  2010.0      Fighting
#
# ...

# %%
df.groupby('Platform').sum()[["Global"]].sort_values(by = "Global", ascending = False)

#df.groupby('Platform').sum()[['Global']].sort_values(by = 'Global', ascending = False)
# Out:
# C:\Users\Caroline\AppData\Local\Temp\ipykernel_6488\3255838584.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Platform').sum()[["Global"]].sort_values(by = "Global", ascending = False)
#           Global
# Platform
# PS2       805.08
# Wii       580.08
# X360      543.30
# DS        453.79
# PS        447.65
# PS3       443.92
# NES       213.14
# GB        197.98
# PC        169.95
# GBA       157.05
# N64       147.47
# SNES      134.85
# PSP       108.25
# XB        108.03
# GC        103.13
# 3DS        36.75
# GEN        26.79
# DC          8.84
# SAT         4.16
# WiiU        3.36
# SCD         1.50
# PSV         0.93

# %%
df.groupby('Game Title').sum()[["Global"]].sort_values(by = "Global", ascending = False).head(10)
# Out:
# C:\Users\Caroline\AppData\Local\Temp\ipykernel_6488\4257524727.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Game Title').sum()[["Global"]].sort_values(by = "Global", ascending = False).head(10)
#                                 Global
# Game Title
# Wii Sports                       81.12
# Super Mario Bros.                40.24
# Tetris                           35.84
# Mario Kart Wii                   33.55
# Wii Sports Resort                31.52
# New Super Mario Bros.            29.08
# Wii Play                         28.71
# Duck Hunt                        28.31
# Call of Duty: Modern Warfare 3   27.52
# Call of Duty: Black Ops          27.03

# %%
df.groupby(["Game Title","Platform"]).sum()[["Global"]].sort_values(by = "Global", ascending = False).head(10)
# Out:
# C:\Users\Caroline\AppData\Local\Temp\ipykernel_6488\2867547269.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["Game Title","Platform"]).sum()[["Global"]].sort_values(by = "Global", ascending = False).head(10)
#                                     Global
# Game Title                Platform
# Wii Sports                Wii        81.12
# Super Mario Bros.         NES        40.24
# Mario Kart Wii            Wii        33.55
# Wii Sports Resort         Wii        31.52
# Tetris                    GB         30.26
# New Super Mario Bros.     DS         29.08
# Wii Play                  Wii        28.71
# Duck Hunt                 NES        28.31
# New Super Mario Bros. Wii Wii        26.75
# Nintendogs                DS         24.50

# %%
df['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'PS2', 'SNES', 'X360', 'GBA', 'PS3',
#        'N64', 'PC', 'PS', 'XB', '3DS', 'PSP', 'GC', 'GEN', 'DC', 'SAT',
#        'WiiU', 'SCD', 'PSV'], dtype=object)

# %%
top10p.index
top10p_df=df[df["Platform"].isin(list(top10p.index))].copy()
toptitles=top10p_df.groupby(["Game Title","Platform"]).sum()[["Global"]].sort_values(by = "Global", ascending = False)
# Out:
# C:\Users\Caroline\AppData\Local\Temp\ipykernel_6488\3016026167.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   top10p_df.groupby(["Game Title","Platform"]).sum()[["Global"]].sort_values(by = "Global", ascending = False)
#                                          Global
# Game Title                     Platform
# Wii Sports                     Wii        81.12
# Super Mario Bros.              NES        40.24
# Mario Kart Wii                 Wii        33.55
# Wii Sports Resort              Wii        31.52
# Tetris                         GB         30.26
# ...                                         ...
# Medal of Honor: Warfighter     X360        0.83
# Army of Two: The 40th Day      X360        0.83
# Xenoblade Chronicles           Wii         0.83
# ...

# %%
top10p=df.groupby('Platform').sum()[["Global"]].sort_values(by = "Global", ascending = False).head(10)
top10p.index
# Out:
# C:\Users\Caroline\AppData\Local\Temp\ipykernel_6488\1579892641.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   top10p=df.groupby('Platform').sum()[["Global"]].sort_values(by = "Global", ascending = False).head(10)
# Index(['PS2', 'Wii', 'X360', 'DS', 'PS', 'PS3', 'NES', 'GB', 'PC', 'GBA'], dtype='object', name='Platform')

# %%
top10p_df=df[df["Platform"].isin(list(top10p.index))].copy()
toptitles = top10p_df.groupby(["Game Title","Platform"]).sum()[["Global"]].sort_values(by = "Global", ascending = False).reset_index().set_index('Game Title')
                                 
for i in list(top10p.index):
    print(i)
    temp_df = toptitles[toptitles['Platform'] == i].copy()
    print(list(temp_df.head(10).index))
# Out:
# PS2
# ['Grand Theft Auto: San Andreas', 'Grand Theft Auto: Vice City', 'Gran Turismo 3: A-Spec', 'Grand Theft Auto III', 'Gran Turismo 4', 'Final Fantasy X', 'Need for Speed Underground', 'Need for Speed Underground 2', 'Medal of Honor: Frontline', 'Metal Gear Solid 2: Sons of Liberty']
# Wii
# ['Wii Sports', 'Mario Kart Wii', 'Wii Sports Resort', 'Wii Play', 'New Super Mario Bros. Wii', 'Wii Fit', 'Wii Fit Plus', 'Super Smash Bros. Brawl', 'Super Mario Galaxy', 'Just Dance 3']
# X360
# ['Kinect Adventures!', 'Call of Duty: Modern Warfare 3', 'Call of Duty: Black Ops', 'Call of Duty: Modern Warfare 2', 'Call of Duty: Black Ops II', 'Halo 3', 'Grand Theft Auto IV', 'Halo: Reach', 'Call of Duty 4: Modern Warfare', 'Halo 4']
# DS
# ...

# %%
top_games=toptitles[toptitles["Platform"]=="PS2"]
# Out:
#                                     Platform  Global
# Game Title
# Grand Theft Auto: San Andreas            PS2   20.81
# Grand Theft Auto: Vice City              PS2   16.15
# Gran Turismo 3: A-Spec                   PS2   14.88
# Grand Theft Auto III                     PS2   13.10
# Gran Turismo 4                           PS2   11.36
# Final Fantasy X                          PS2    8.05
# Need for Speed Underground               PS2    7.20
# Need for Speed Underground 2             PS2    6.90
# Medal of Honor: Frontline                PS2    6.83
# Metal Gear Solid 2: Sons of Liberty      PS2    6.05

# %%
a = df.groupby(['Genre', 'Year']).sum()[['Global']].sort_index().pct_change().dropna().reset_index()
genres = a['Genre'].unique()
for i in genres:
    temp_df = a[a['Genre'] == i].copy()
    plt.figure(figsize = (10, 2))
    plt.plot(temp_df['Year'], temp_df['Global'])
    plt.title(i)
    plt.show()
# Out:
# C:\Users\Caroline\AppData\Local\Temp\ipykernel_6488\3370494303.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   a = df.groupby(['Genre', 'Year']).sum()[['Global']].sort_index().pct_change().dropna().reset_index()

# %%
#x = ['PS2', 'Wii', 'X360', 'DS', 'PS', 'PS3', 'NES', 'GB', 'PC', 'GBA']
toptitles[toptitles["Platform"]=="Wii"]
# Out:
#                               Platform  Global
# Game Title
# Wii Sports                         Wii   81.12
# Mario Kart Wii                     Wii   33.55
# Wii Sports Resort                  Wii   31.52
# Wii Play                           Wii   28.71
# New Super Mario Bros. Wii          Wii   26.75
# ...                                ...     ...
# Samba De Amigo                     Wii    0.85
# Monster 4X4: World Circuit         Wii    0.85
# F1 2009                            Wii    0.84
# Guitar Hero: Warriors of Rock      Wii    0.84
# Xenoblade Chronicles               Wii    0.83
#
# [156 rows x 2 columns]

# %%
toptitles[toptitles["Platform"]=="X360"]
# Out:
#                                Platform  Global
# Game Title
# Kinect Adventures!                 X360   19.90
# Call of Duty: Modern Warfare 3     X360   14.87
# Call of Duty: Black Ops            X360   13.90
# Call of Duty: Modern Warfare 2     X360   13.00
# Call of Duty: Black Ops II         X360   11.85
# ...                                 ...     ...
# NBA 2K8                            X360    0.84
# WWE SmackDown vs. Raw 2011         X360    0.83
# Medal of Honor: Warfighter         X360    0.83
# Army of Two: The 40th Day          X360    0.83
# DiRT                               X360    0.83
#
# [218 rows x 2 columns]

# %%
toptitles[toptitles["Platform"]=="DS"]
# Out:
#                                              Platform  Global
# Game Title
# New Super Mario Bros.                              DS   29.08
# Nintendogs                                         DS   24.50
# Mario Kart DS                                      DS   22.47
# Brain Age: Train Your Brain in Minutes a Day       DS   20.02
# Pokémon Diamond / Pearl Version                    DS   18.05
# ...                                               ...     ...
# FIFA Soccer 08                                     DS    0.85
# Peppa Pig: The Game                                DS    0.85
# Petz Dogz Fashion                                  DS    0.84
# Wizards of Waverly Place                           DS    0.84
# Kingdom Hearts Re:coded                            DS    0.84
#
# [149 rows x 2 columns]
